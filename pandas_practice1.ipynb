# %%
#pandas 사용
import numpy as np
import pandas as pd

# %%
#series : 1차원 어레이에 Index,Name을 가지고 있는 데이터 구조
#index의 default값은 숫자지만 직접 index,name 설정 가능 
series = pd.Series([1,2,3,4,5], index=["a","b","c","d","e"], name="alphabet")
series
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: alphabet, dtype: int64

# %%
#DataFrame : 2차원의 매트릭스에 Index,Columns를 가지고 있는 데이터 구조
#Series의 Name들은 DataFrame의 Columns이 됨
#마찬가지로 index를 설정하지 않은 경우 0부터 시작하는 값가짐
df = pd.DataFrame({"number":[1,2,3,4,5],"alphabet":["a","b","c","d","e"]}, index = ["가","나","다","라","마"])

df
# Out:
#    number alphabet
# 가       1        a
# 나       2        b
# 다       3        c
# 라       4        d
# 마       5        e

# %%
import pandas as pd
from faker import Faker

#fake 데이터를 생성하기 위한 준비
#faker는 테스트에 사용할 수 있는 랜덤한 데이터 생성
Faker.seed(0)
fake=Faker()

#500개의 랜덤 데이터 생성, 데이터 프레임 만들기
data= [fake.simple_profile() for _ in range(500)]
df=pd.DataFrame(data)

# %%
pip install jupyter pandas faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: backcall in c:\users\dustn\anaconda3\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->jupyter) (0.2.0)
# ...
#
# ...

# %%
#위에서부터 10개 데이터 추출
df.head(10)
# Out:
#          username               name sex  \
# 0       ysullivan        Jason Green   M
# 1       davismary  Mrs. Sharon Green   F
# 2          lisa83     Doris Martinez   F
# 3  daviskatherine        Vicki Green   F
# 4  thorntonnathan       David Dennis   M
# 5         qoliver        Amy Shelton   F
# 6        alyssa19   Mrs. Megan Bruce   F
# 7           sbell      Joshua Taylor   M
# 8           frose          Amy Miles   F
# 9       bairdemma        Daniel Love   M
#
#                                              address                     mail  \
# 0   9382 Taylor Court Suite 892\nCoreyland, TX 43780        wcastro@yahoo.com
# 1         753 Padilla Circles\nNew Jeffrey, FL 71671       udavis@hotmail.com
# 2                         USNV Wallace\nFPO AP 50950      barbara42@gmail.com
# 3        86848 Melissa Springs\nRileymouth, TN 84543  christopher91@yahoo.com
# 4  12309 Anthony Roads Apt. 991\nDavisville, PA 0...     susanlopez@gmail.com
# ...

# %%
#아래서부터 10개 데이터 추출
df.tail(10)
# Out:
#             username                  name sex  \
# 490           lisa53         Joseph Decker   M
# 491    nicholebenson       Joseph Williams   M
# 492   petersenyvonne  Christopher Calderon   M
# 493         sandra33           Kurt Turner   M
# 494         jeremy98     Michael Alexander   M
# 495  krystalmartinez         Abigail Mccoy   F
# 496         nmendoza       Sharon Richards   F
# 497     autumnwilcox           Kelly Patel   F
# 498     emilyjohnson      Joseph Castaneda   M
# 499     brianfarrell    Margaret Schneider   F
#
#                                                address  \
# 490                   Unit 4091 Box 5702\nDPO AA 09475
# 491                          USCGC Smith\nFPO AA 76525
# 492   595 Jones Vista Suite 797\nTerrellberg, MO 90464
# 493  961 Richard Station Suite 408\nAlexanderton, A...
# 494       46405 Steven Course\nMartinezmouth, OK 27893
# 495          970 Robert Mountain\nMillerbury, TX 06383
# ...

# %%
# 위치 기반 인덱싱
#3번째 데이터부터 5번째 데이터 추출
df.iloc[2:5]
# Out:
#          username            name sex  \
# 2          lisa83  Doris Martinez   F
# 3  daviskatherine     Vicki Green   F
# 4  thorntonnathan    David Dennis   M
#
#                                              address                     mail  \
# 2                         USNV Wallace\nFPO AP 50950      barbara42@gmail.com
# 3        86848 Melissa Springs\nRileymouth, TN 84543  christopher91@yahoo.com
# 4  12309 Anthony Roads Apt. 991\nDavisville, PA 0...     susanlopez@gmail.com
#
#     birthdate
# 2  2016-11-01
# 3  1984-12-07
# 4  1970-04-04

# %%
#3~5데이터 중 첫번째(이름) 데이터 추출
df.iloc[2:5, 0]
# Out:
# 2            lisa83
# 3    daviskatherine
# 4    thorntonnathan
# Name: username, dtype: object

# %%
#앞에 안써주면 처음부터 (0)번컬럼부터 1번까지 두개의 컬럼
df.iloc[[1,2,4], :2]
# Out:
#          username               name
# 1       davismary  Mrs. Sharon Green
# 2          lisa83     Doris Martinez
# 4  thorntonnathan       David Dennis

# %%
#0~4컬럼을 1,2,3,5번 항목 출력
df.iloc[:5,[1,2,3,5]]
# Out:
#                 name sex                                            address  \
# 0        Jason Green   M   9382 Taylor Court Suite 892\nCoreyland, TX 43780
# 1  Mrs. Sharon Green   F         753 Padilla Circles\nNew Jeffrey, FL 71671
# 2     Doris Martinez   F                         USNV Wallace\nFPO AP 50950
# 3        Vicki Green   F        86848 Melissa Springs\nRileymouth, TN 84543
# 4       David Dennis   M  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
#
#     birthdate
# 0  1948-01-26
# 1  1971-08-17
# 2  2016-11-01
# 3  1984-12-07
# 4  1970-04-04

# %%
# ::-1로 순서를 뒤집을 수 있음
df.iloc[::-1,:].head()
# Out:
#             username                name sex  \
# 499     brianfarrell  Margaret Schneider   F
# 498     emilyjohnson    Joseph Castaneda   M
# 497     autumnwilcox         Kelly Patel   F
# 496         nmendoza     Sharon Richards   F
# 495  krystalmartinez       Abigail Mccoy   F
#
#                                              address  \
# 499        5061 Hoffman Green\nGarciahaven, OH 49348
# 498  5100 Mary Green Suite 895\nCurtisbury, KS 74948
# 497       22836 Warren Hills\nNorth Sierra, MI 89852
# 496          4051 Knapp Pike\nEast Cynthia, IN 71015
# 495        970 Robert Mountain\nMillerbury, TX 06383
#
#                          mail   birthdate
# 499        mark68@hotmail.com  2014-03-17
# 498     myersalicia@gmail.com  1946-11-08
# 497   barneswanda@hotmail.com  1915-04-30
# 496  sanderstiffany@yahoo.com  1953-03-28
# 495         tmurphy@yahoo.com  1973-02-04

# %%
# 레이블 기반 인덱싱
#레이블로 원하는 데이터 추출
df = df.set_index("username")
df.head()
# Out:
#                              name sex  \
# username
# ysullivan             Jason Green   M
# davismary       Mrs. Sharon Green   F
# lisa83             Doris Martinez   F
# daviskatherine        Vicki Green   F
# thorntonnathan       David Dennis   M
#
#                                                           address  \
# username
# ysullivan        9382 Taylor Court Suite 892\nCoreyland, TX 43780
# davismary              753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83                                 USNV Wallace\nFPO AP 50950
# daviskatherine        86848 Melissa Springs\nRileymouth, TN 84543
# thorntonnathan  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
#
#                                    mail   birthdate
# username
# ysullivan             wcastro@yahoo.com  1948-01-26
# davismary            udavis@hotmail.com  1971-08-17
# lisa83              barbara42@gmail.com  2016-11-01
# daviskatherine  christopher91@yahoo.com  1984-12-07
# ...

# %%
df.loc["ysullivan"]
# Out:
# name                                              Jason Green
# sex                                                         M
# address      9382 Taylor Court Suite 892\nCoreyland, TX 43780
# mail                                        wcastro@yahoo.com
# birthdate                                          1948-01-26
# Name: ysullivan, dtype: object

# %%
df.loc[["davismary","lisa83","daviskatherine"],["name","address"]]
# Out:
#                              name                                      address
# username
# davismary       Mrs. Sharon Green   753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83             Doris Martinez                   USNV Wallace\nFPO AP 50950
# daviskatherine        Vicki Green  86848 Melissa Springs\nRileymouth, TN 84543

# %%
#행 열 변환
# df=df.T

# %%
#기존 인덱스 초기화 -> reset_index()메소드 사용
df = df.reset_index()
df
# Out:
#             username                name sex  \
# 0          ysullivan         Jason Green   M
# 1          davismary   Mrs. Sharon Green   F
# 2             lisa83      Doris Martinez   F
# 3     daviskatherine         Vicki Green   F
# 4     thorntonnathan        David Dennis   M
# ..               ...                 ...  ..
# 495  krystalmartinez       Abigail Mccoy   F
# 496         nmendoza     Sharon Richards   F
# 497     autumnwilcox         Kelly Patel   F
# 498     emilyjohnson    Joseph Castaneda   M
# 499     brianfarrell  Margaret Schneider   F
#
#                                                address  \
# 0     9382 Taylor Court Suite 892\nCoreyland, TX 43780
# 1           753 Padilla Circles\nNew Jeffrey, FL 71671
# 2                           USNV Wallace\nFPO AP 50950
# 3          86848 Melissa Springs\nRileymouth, TN 84543
# 4    12309 Anthony Roads Apt. 991\nDavisville, PA 0...
# ..                                                 ...
# ...

# %%
df=df.set_index("username")
df.head()
# Out:
#                              name sex  \
# username
# ysullivan             Jason Green   M
# davismary       Mrs. Sharon Green   F
# lisa83             Doris Martinez   F
# daviskatherine        Vicki Green   F
# thorntonnathan       David Dennis   M
#
#                                                           address  \
# username
# ysullivan        9382 Taylor Court Suite 892\nCoreyland, TX 43780
# davismary              753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83                                 USNV Wallace\nFPO AP 50950
# daviskatherine        86848 Melissa Springs\nRileymouth, TN 84543
# thorntonnathan  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
#
#                                    mail   birthdate
# username
# ysullivan             wcastro@yahoo.com  1948-01-26
# davismary            udavis@hotmail.com  1971-08-17
# lisa83              barbara42@gmail.com  2016-11-01
# daviskatherine  christopher91@yahoo.com  1984-12-07
# ...

# %%
#인덱스 설정 -> set_index("바꿀인덱스네임")

#인덱스 선택 & 확장 reindex
df_temp = df.head(10) # 임시 df 생성 후 위에서 10개 데이터 선택
df_temp
# Out:
#                              name sex  \
# username
# ysullivan             Jason Green   M
# davismary       Mrs. Sharon Green   F
# lisa83             Doris Martinez   F
# daviskatherine        Vicki Green   F
# thorntonnathan       David Dennis   M
# qoliver               Amy Shelton   F
# alyssa19         Mrs. Megan Bruce   F
# sbell               Joshua Taylor   M
# frose                   Amy Miles   F
# bairdemma             Daniel Love   M
#
#                                                           address  \
# username
# ysullivan        9382 Taylor Court Suite 892\nCoreyland, TX 43780
# davismary              753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83                                 USNV Wallace\nFPO AP 50950
# daviskatherine        86848 Melissa Springs\nRileymouth, TN 84543
# thorntonnathan  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
# qoliver               456 Bruce Mountain\nNew Craigfurt, KS 47497
# ...

# %%
df_temp.reindex(["ysullivan","frose","davismary"])
# Out:
#                         name sex  \
# username
# ysullivan        Jason Green   M
# frose              Amy Miles   F
# davismary  Mrs. Sharon Green   F
#
#                                                     address  \
# username
# ysullivan  9382 Taylor Court Suite 892\nCoreyland, TX 43780
# frose                      PSC 9007, Box 5470\nAPO AA 25142
# davismary        753 Padilla Circles\nNew Jeffrey, FL 71671
#
#                             mail   birthdate
# username
# ysullivan      wcastro@yahoo.com  1948-01-26
# frose      monroedavid@gmail.com  1959-09-21
# davismary     udavis@hotmail.com  1971-08-17

# %%
#Columns 조작

#Column 이름 변경
#df.columns 로 데이터 프레임의 columns 확인
df.columns = ["Name","Gender","address","mail","Birth"]
df.index.name="Username"
df.head()
# Out:
#                              Name Gender  \
# Username
# ysullivan             Jason Green      M
# davismary       Mrs. Sharon Green      F
# lisa83             Doris Martinez      F
# daviskatherine        Vicki Green      F
# thorntonnathan       David Dennis      M
#
#                                                           address  \
# Username
# ysullivan        9382 Taylor Court Suite 892\nCoreyland, TX 43780
# davismary              753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83                                 USNV Wallace\nFPO AP 50950
# daviskatherine        86848 Melissa Springs\nRileymouth, TN 84543
# thorntonnathan  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
#
#                                    mail       Birth
# Username
# ysullivan             wcastro@yahoo.com  1948-01-26
# davismary            udavis@hotmail.com  1971-08-17
# lisa83              barbara42@gmail.com  2016-11-01
# daviskatherine  christopher91@yahoo.com  1984-12-07
# ...

# %%
# 이렇게 하면 컬럼 모두 입력안해도 바꿀 수 있음
df=df.rename(columns={"Birth":"Birthdate"})
df.head()
# Out:
#                              Name Gender  \
# Username
# ysullivan             Jason Green      M
# davismary       Mrs. Sharon Green      F
# lisa83             Doris Martinez      F
# daviskatherine        Vicki Green      F
# thorntonnathan       David Dennis      M
#
#                                                           address  \
# Username
# ysullivan        9382 Taylor Court Suite 892\nCoreyland, TX 43780
# davismary              753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83                                 USNV Wallace\nFPO AP 50950
# daviskatherine        86848 Melissa Springs\nRileymouth, TN 84543
# thorntonnathan  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
#
#                                    mail   Birthdate
# Username
# ysullivan             wcastro@yahoo.com  1948-01-26
# davismary            udavis@hotmail.com  1971-08-17
# lisa83              barbara42@gmail.com  2016-11-01
# daviskatherine  christopher91@yahoo.com  1984-12-07
# ...

# %%
#새로운 Columns 추가
# df[<추가할 컬럼명>] = <추가할 Series>
# Birthdate를 pandas에서 인식할 수 있는 Datetime 타입으로 바꿔주는 과정
df["Birthdate"] = pd.to_datetime(df["Birthdate"])

# Age 컬럼 추가
df['Age'] = pd.Timestamp.now().year - df["Birthdate"].dt.year
df.head()
# Out:
#                              Name Gender  \
# Username
# ysullivan             Jason Green      M
# davismary       Mrs. Sharon Green      F
# lisa83             Doris Martinez      F
# daviskatherine        Vicki Green      F
# thorntonnathan       David Dennis      M
#
#                                                           address  \
# Username
# ysullivan        9382 Taylor Court Suite 892\nCoreyland, TX 43780
# davismary              753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83                                 USNV Wallace\nFPO AP 50950
# daviskatherine        86848 Melissa Springs\nRileymouth, TN 84543
# thorntonnathan  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
#
#                                    mail  Birthdate  Age
# Username
# ysullivan             wcastro@yahoo.com 1948-01-26   73
# davismary            udavis@hotmail.com 1971-08-17   50
# lisa83              barbara42@gmail.com 2016-11-01    5
# daviskatherine  christopher91@yahoo.com 1984-12-07   37
# ...

# %%
# Columns 제거
#df.drop 메소드 사용
df=df.drop("Birthdate",axis=1) #axis에 1대신 "columns"가 들어가도 됨
df.head()
# Out:
#                              Name Gender  \
# Username
# ysullivan             Jason Green      M
# davismary       Mrs. Sharon Green      F
# lisa83             Doris Martinez      F
# daviskatherine        Vicki Green      F
# thorntonnathan       David Dennis      M
#
#                                                           address  \
# Username
# ysullivan        9382 Taylor Court Suite 892\nCoreyland, TX 43780
# davismary              753 Padilla Circles\nNew Jeffrey, FL 71671
# lisa83                                 USNV Wallace\nFPO AP 50950
# daviskatherine        86848 Melissa Springs\nRileymouth, TN 84543
# thorntonnathan  12309 Anthony Roads Apt. 991\nDavisville, PA 0...
#
#                                    mail  Age
# Username
# ysullivan             wcastro@yahoo.com   73
# davismary            udavis@hotmail.com   50
# lisa83              barbara42@gmail.com    5
# daviskatherine  christopher91@yahoo.com   37
# thorntonnathan     susanlopez@gmail.com   51

# %%
#DataFrame 합치기
#data2만들기
import random
data2 = {
    "Salary": [random.randrange(10, 10000) for _ in range(150)],
    "WeeklyDrink": [random.randrange(0, 11) for _ in range(150)],
    "WeeklyExercise": [random.randrange(0, 6) for _ in range(150)]
}
df2 = pd.DataFrame(data2,index = df.sample(150).index)
df2.head()
# Out:
#                   Salary  WeeklyDrink  WeeklyExercise
# Username
# johnstonjennifer    9626            8               3
# aberg               5320           10               3
# jamiegreen          7215            5               0
# carrillochloe       4112            9               5
# hernandezannette    9799            6               0

# %%
#pd.merge로 두개의 프레임 합치기
df = pd.merge(df, df2, on="Username", how="left")
df.head(20)
# Out:
#                                 Name Gender  \
# Username
# ysullivan                Jason Green      M
# davismary          Mrs. Sharon Green      F
# lisa83                Doris Martinez      F
# daviskatherine           Vicki Green      F
# thorntonnathan          David Dennis      M
# qoliver                  Amy Shelton      F
# alyssa19            Mrs. Megan Bruce      F
# sbell                  Joshua Taylor      M
# frose                      Amy Miles      F
# bairdemma                Daniel Love      M
# angela59               Andrew Harris      M
# nelsonedward           George Oliver      M
# turnerjessica          Brian Jimenez      M
# richardsonvanessa    Miguel Robinson      M
# danielcarlson            Jamie Payne      F
# marshzachary            Nathan Roman      M
# burgessrebecca       Meghan Trujillo      F
# olsondonald              Monica Cook      F
# ibarrachelsea         Richard Waters      M
# jerryfrank              Tony Estrada      M
#
# ...
